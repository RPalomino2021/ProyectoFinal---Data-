-- %%
-- =========================================================
-- CREACIÓN DE EXTERNAL LOCATION PARA CAPA METASTORE
-- =========================================================

-- Crea una ubicación externa llamada extl-metastore si no existe
-- Apunta al contenedor bronze dentro del storage adlssmartdata1201rp
-- Utiliza el Storage Credential llamado credential_rp
CREATE EXTERNAL LOCATION IF NOT EXISTS `extl-metastore` 
URL 'abfss://metastore-rp@adlssmartdata1201rp.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential_rp);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- =========================================================
-- CREACIÓN DE EXTERNAL LOCATION PARA CAPA BRONZE
-- =========================================================

-- Crea una ubicación externa llamada extl-bronze si no existe
-- Apunta al contenedor bronze dentro del storage adlssmartdata1201rp
-- Utiliza el Storage Credential llamado credential_rp
CREATE EXTERNAL LOCATION IF NOT EXISTS `extl-bronze` 
URL 'abfss://bronze-rp@adlssmartdata1201rp.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `credential_rp`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- =========================================================
-- CREACIÓN DE EXTERNAL LOCATION PARA CAPA SILVER
-- =========================================================

-- Crea una ubicación externa llamada extl-silver si no existe
-- Apunta al contenedor silver dentro del storage adlssmartdata1201rp
-- Utiliza el Storage Credential credential_rp para autenticación
CREATE EXTERNAL LOCATION IF NOT EXISTS `extl-silver`
URL 'abfss://silver-rp@adlssmartdata1201rp.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `credential_rp`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- =========================================================
-- CREACIÓN DE EXTERNAL LOCATION PARA CAPA GOLD
-- =========================================================

-- Crea una ubicación externa llamada extl-gold si no existe
-- Apunta al contenedor gold dentro del storage adlssmartdata1201rp
-- Utiliza el Storage Credential credential_rp
CREATE EXTERNAL LOCATION IF NOT EXISTS `extl-gold`
URL 'abfss://gold-rp@adlssmartdata1201rp.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `credential_rp`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- =========================================================
-- CREACIÓN DEL CATÁLOGO EN UNITY CATALOG
-- =========================================================

-- Crea el catálogo catalog_dev si no existe
-- Define como ubicación administrada el contenedor metastore-rp
-- dentro del storage adlssmartdata1201rp
CREATE CATALOG IF NOT EXISTS catalog_RP
MANAGED LOCATION 'abfss://metastore-rp@adlssmartdata1201rp.dfs.core.windows.net/catalog_RP/';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- =========================================================
-- CREACIÓN DE ESQUEMAS (SCHEMAS) PARA ARQUITECTURA MEDALLION
-- =========================================================

-- Crea el esquema bronze dentro del catálogo catalog_RP
-- Define como ubicación administrada el contenedor bronze-rp
CREATE SCHEMA IF NOT EXISTS catalog_RP.bronze
MANAGED LOCATION 'abfss://bronze-rp@adlssmartdata1201rp.dfs.core.windows.net/';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- Crea el esquema silver dentro del catálogo catalog_RP
-- Define como ubicación administrada el contenedor silver-rp
CREATE SCHEMA IF NOT EXISTS catalog_RP.silver
MANAGED LOCATION 'abfss://silver-rp@adlssmartdata1201rp.dfs.core.windows.net/';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
-- Crea el esquema gold dentro del catálogo catalog_RP
-- Define como ubicación administrada el contenedor gold-rp
CREATE SCHEMA IF NOT EXISTS catalog_RP.gold
MANAGED LOCATION 'abfss://gold-rp@adlssmartdata1201rp.dfs.core.windows.net/';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
